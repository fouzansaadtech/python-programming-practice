# %%
 # Create a function called safe_division(). 


'''Requirements: 
 Ask the user to enter two numbers.  
 Divide the first number by the second.  
 Handle:  
 ValueError if the user enters non-numeric input.  
 ZeroDivisionError if the second number is 0.  
 Use finally to print "Calculation completed."  
 Use an if condition to check whether the result is positive or negative.  '''

def  safe_division():
 try:
    num_1=int(input("Enter 1st no:"))
    num_2=int(input("Enter 2nd no:"))

    div= num_1 / num_2

    if div%2==0:
        print("Postive")
    else:
        print("Negative")

 except ValueError:
    print("The user enters non-numeric input")
 except ZeroDivisionError:
    print("The second number is 0")

 finally:
    print("Calculation completed")

safe_division()
# Out:
# Postive
# Calculation completed
