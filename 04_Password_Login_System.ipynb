# %%
#Password Login System
  
#Create a function called login(). 

'''Requirements: 
 Ask the user to enter a numeric password.  
 Handle ValueError if the password is not a number.  
 Allow only 3 attempts using a loop.  
 Use an if condition to check whether the password matches a predefined password.  
 If the password is correct, print "Login Successful".  
 Otherwise, print "Invalid Password".  
 Use finally to print "Login process ended."'''

def login():
 attempt=0
 while attempt<3:
    try:
        enter=int(input("Enter a password:"))
        if enter==2827:
                print("Login Sucessfull")
                break
        else:
                print("Invalid Password")
                attempt+=1
    except ValueError:
        print("The password is not a number")
        attempt+=1
    finally:
        print("Login process ended")

login()
# Out:
# Invalid Password
# Login process ended
# Invalid Password
# Login process ended
# Invalid Password
# Login process ended
